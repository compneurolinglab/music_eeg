# %%
import os
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model

# Define feature extractor
def build_feature_extractor(base_model):
    layer_names = ["conv1", "conv2", "conv3", "conv4_W", "conv5_W", "conv4_G", "conv5_G"]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    feature_model = tf.keras.Model(inputs=base_model.input, outputs=outputs)
    return feature_model

# Load model
model = load_model("fine_tuned_model.h5")
feature_model = build_feature_extractor(model)

# Load cochleagram data
music1vocal_folder = "TestSet/Music1"
npy_files = sorted([
    os.path.join(music1vocal_folder, f)
    for f in os.listdir(music1vocal_folder)
    if f.endswith(".npy")
])

# Create folders to save the features
save_root = "word_features1"
layer_names = ["conv1", "conv2", "conv3", "conv4_W", "conv5_W", "conv4_G", "conv5_G"]

os.makedirs(save_root, exist_ok=True)
for layer in layer_names:
    os.makedirs(os.path.join(save_root, layer), exist_ok=True)

# Extract and save the features
for i, sample_path in enumerate(npy_files):
    sample = np.load(sample_path)

    if sample.ndim == 2:
        sample = np.expand_dims(sample, axis=-1)
    sample = sample.reshape(1, 256, 256, 1)

    feature_outputs = feature_model.predict(sample)

    filename = os.path.splitext(os.path.basename(sample_path))[0]
    for layer_name, feat in zip(layer_names, feature_outputs):
        save_path = os.path.join(save_root, layer_name, f"{filename}.npy")
        np.save(save_path, feat)

    print(f"Features saved: {filename}")
# Out:
# 2025-03-27 00:46:04.005850: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-27 00:46:04.022655: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743007564.039628  441803 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743007564.044575  441803 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743007564.058461  441803 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743007564.058479  441803 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743007564.058481  441803 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743007564.058482  441803 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-27 00:46:04.062849: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1743007566.374196  441803 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46816 MB memory:  -> device: 0, name: NVIDIA L20, pci bus id: 0000:71:01.0, compute capability: 8.9
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743007568.104162  442240 service.cc:152] XLA service 0x7fde88016e80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743007568.104184  442240 service.cc:160]   StreamExecutor device (0): NVIDIA L20, Compute Capability 8.9
# 2025-03-27 00:46:08.112782: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1743007568.162950  442240 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step
# Features saved: Music1Seg_part_001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# I0000 00:00:1743007568.817727  442240 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Features saved: Music1Seg_part_002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Features saved: Music1Seg_part_004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Features saved: Music1Seg_part_018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_020
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_022
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Features saved: Music1Seg_part_025
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Features saved: Music1Seg_part_026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_027
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Features saved: Music1Seg_part_029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_030
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_031
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_034
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_037
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_038
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_039
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_040
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_041
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_047
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Features saved: Music1Seg_part_048
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_049
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_050
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_052
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Features saved: Music1Seg_part_055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_059
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_060
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_061
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_062
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_063
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_065
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_070
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_071
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_072
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_073
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_074
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_076
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_084
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Features saved: Music1Seg_part_085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_090
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_098
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Features saved: Music1Seg_part_101
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_102
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_108
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Features saved: Music1Seg_part_114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_124
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Features saved: Music1Seg_part_125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Features saved: Music1Seg_part_126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Features saved: Music1Seg_part_127
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Features saved: Music1Seg_part_128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_129
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Features saved: Music1Seg_part_130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_131
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_132
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_134
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_136
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_137
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_139
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_140
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_141
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_142
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_143
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Features saved: Music1Seg_part_144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_146
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_147
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_148
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Features saved: Music1Seg_part_150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_151
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_153
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_154
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_158
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_159
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_160
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_161
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_163
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_165
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_166
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Features saved: Music1Seg_part_167
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Features saved: Music1Seg_part_168
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Features saved: Music1Seg_part_171
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Features saved: Music1Seg_part_172
